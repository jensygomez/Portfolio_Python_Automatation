# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst and Automatation with Python
#
# **Date:**         12 March 2024
#
# **Modified** 17 March 2024
#
# **Location:**     Vila Izabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# **Title:**
# # Python Counter Function: Counting Up or Down
#
# **Statement:**
# Create a Python function named `counter` that takes two parameters `start` and `stop`. Depending on whether `start` is greater or lesser than `stop`, the function will count either up or down, including the start and stop values. If counting up, it will return a string indicating "Counting up:" followed by the numbers separated by commas. If counting down, it will return a string indicating "Counting down:" followed by the numbers separated by commas.
#
# **Step-by-Step:**
# 1. Define a function named `counter` which takes two parameters, `start` and `stop`.
# 2. Check if `start` is greater than `stop`.
#    - If true, initialize `return_string` to "Counting down: ".
#      - Use a while loop to iterate from `start` down to `stop`, inclusive.
#      - Inside the loop, append the current value of `start` to `return_string` as a string.
#      - If `start` is greater than `stop`, append a comma after the number.
#      - Decrement `start` by 1 in each iteration.
# 3. If `start` is not greater than `stop`, initialize `return_string` to "Counting up: ".
#    - Use a while loop to iterate from `start` up to `stop`, inclusive.
#      - Inside the loop, append the current value of `start` to `return_string` as a string.
#      - If `start` is less than `stop`, append a comma after the number.
#      - Increment `start` by 1 in each iteration.
# 4. Return the `return_string`.
# 5. Outside the function, call `counter` with different sets of parameters (e.g., `print(counter(1, 10))`, `print(counter(2, 1))`, `print(counter(5, 5))`) to test its behavior.

# %%
# Step 1: Define a function named `counter` which takes two parameters, `start` and `stop`.


    # Step 2: Check if `start` is greater than `stop`.


        # Step 2a: If true, initialize `return_string` to "Counting down: ".
        
        

        # Step 2a (i): Use a while loop to iterate from `start` down to `stop`, inclusive.
        
        
            # Step 2a (ii): Inside the loop, append the current value of `start` to `return_string` as a string.
        

            
            # Step 2a (iii): If `start` is greater than `stop`, append a comma after the number.
            

            # Step 2a (iv): Decrement `start` by 1 in each iteration.
            
            
    else:
        # Step 3: If `start` is not greater than `stop`, initialize `return_string` to "Counting up: ".
 
        
        # Step 3a: Use a while loop to iterate from `start` up to `stop`, inclusive.
 
            
            # Step 3a (i): Inside the loop, append the current value of `start` to `return_string` as a string.


            # Step 3a (ii): If `start` is less than `stop`, append a comma after the number.

            # Step 3a (iii): Increment `start` by 1 in each iteration.
            
            
    # Step 4: Return the `return_string`.


# Step 5: Outside the function, call `counter` with different sets of parameters to test its behavior.
print(counter(1, 10))  
print(counter(2, 1))   
print(counter(5, 5))

# %%
def counter(start, stop):
    if start > stop:
        return_string = "Counting down: "
        while start >= stop:  
            return_string += str(start)  
            if start > stop:
                return_string += ","
            start -= 1  
    else:
        return_string = "Counting up: "
        while start <= stop:  
            return_string += str(start)  
            if start < stop:
                return_string += ","
            start += 1  
    return return_string

print(counter(1, 10))  
print(counter(2, 1))   
print(counter(5, 5))
