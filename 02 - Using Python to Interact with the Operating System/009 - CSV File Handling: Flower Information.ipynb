# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst and Automatation with Python
#
# **Date:**         13 March 2024
#
# **Location:**     Vila Izabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# **Title:**
# # CSV File Handling: Flower Information
#
# **Statement:**
# The objective of this exercise is to become familiar with handling CSV files in Python. You will need to create a CSV file containing information about different types of flowers, such as their name, color, and plant type (annual or perennial). Then, you will read this file, process its data, and format the information into a string according to a specific format.
#
# **Step-by-Step:**
#
# 1. **Creation of the CSV File:**
#    - Begin by importing the necessary libraries (`os` and `csv`).
#    - Define a function called `create_file(filename)` that takes the filename as an argument.
#    - Within this function, open the file in write mode (`"w"`) using `open()`.
#    - Write the header line of the CSV file with the column names ("name", "color", "type").
#    - Add data about different types of flowers to the file, each on a new line, separating the name, color, and plant type by commas.
#
# 2. **Reading and Formatting Data:**
#    - Define a function called `contents_of_file(filename)` that takes the filename as an argument.
#    - Within this function, initialize an empty string variable called `return_string`.
#    - Call the `create_file(filename)` function to ensure the file exists.
#    - Open the CSV file in read mode (`"r"`).
#    - Use `csv.reader()` to read the rows from the file.
#    - Skip the first row, as it contains the headers.
#    - Process each row of the file:
#      - Extract the name, color, and plant type of the flower from the row.
#      - Format this information into a string according to the required format: "a [color] [name] is [plant type]".
#      - Concatenate this formatted string to the `return_string` variable.
#    - Return the `return_string` string.
#
# 3. **Function Call and Testing:**
#    - Call the `contents_of_file(filename)` function with the filename of the CSV file as an argument.
#    - Print the result to verify that the information has been formatted correctly.
#
# This step-by-step approach will enable you to create a CSV file with flower data and then read and format this data according to the given specifications.

# %%
import os
import csv

# Step 1: Create a file with data in it


    # Open the file in write mode and write data to it


        # Write the header row


        # Write data rows
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

# Step 2: Read the file contents and format the information about each row


    # Initialize an empty string to store the formatted data


    # Call the function to create the file


    # Open the file


        # Read the rows of the file using csv.reader


        # Skip the header row


        # Process each row


            # Extract data from each row


            # Format the return string for data rows only





# Call the function to read the file contents and print the formatted data
print(contents_of_file("flowers.csv"))

# %%
import os
import csv

def create_file(filename):
    with open(filename, "w") as file:
        file.write("name,color,type\n")
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

def contents_of_file(filename):
    return_string = ""
    create_file(filename)
    with open(filename, "r") as file:
        rows = csv.reader(file)
        next(rows)
        for row in rows:
            name, color, plant_type = row
            return_string += "a {} {} is {}\n".format(color, name, plant_type)
    return return_string

print(contents_of_file("flowers.csv"))
