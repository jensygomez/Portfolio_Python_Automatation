# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst and Automatation with Python
#
# **Date:**         13 March 2024
#
# **Location:**     Vila Izabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# # **Analyzing Flower Data: Reading and Formatting a CSV File in Python**
#
# **Prompt:**
# In this exercise, we'll work with a CSV file containing information about different types of flowers, including their name, color, and type (annual or perennial). The goal is to create a Python script that reads this file, formats the information from each row, and then returns a string with the format "A {color} {name} is {type}". For example, "A pink carnation is annual".
#
# **Step-by-Step:**
# 1. **Creating the CSV File:**
#    - Create a function called `create_file` that accepts a filename as an argument.
#    - Within this function, open the file in write mode and write the following header and data lines:
#      ```
#      name,color,type
#      carnation,pink,annual
#      daffodil,yellow,perennial
#      iris,blue,perennial
#      poinsettia,red,perennial
#      sunflower,yellow,annual
#      ```
# 2. **Reading and Formatting Data:**
#    - Create a function called `contents_of_file` that accepts a filename as an argument.
#    - Inside this function, call the `create_file` function to ensure the file exists and contains data.
#    - Open the file in read mode and use `csv.DictReader` to read the rows of the file and convert them into dictionaries.
#    - Iterate over each row of the file and format the information using the structure "A {color} {name} is {type}".
#    - Concatenate each formatted line into an output string.
#    - Return the formatted string.
# 3. **Printing the Result:**
#    - Call the `contents_of_file` function with the filename "flowers.csv".
#    - Print the obtained result, which will display the formatted information of the flowers present in the CSV file.

# %%
# Paso 0: Importación de bibliotecas necesarias
# Biblioteca para interactuar con el sistema operativo
# Biblioteca para trabajar con archivos CSV

# Paso 1: Definición de la función -create_file- con un argumeto -filename -  


    # Crear un archivo CSV con datos de flores

        # Paso 1: Escribir la primera línea del archivo con los encabezados
     
        
        # Paso 1: Escribir datos de las flores en el archivo



# Paso 2: Definición de la función - contents_of_file - con el argumento -filename- 
# para leer y procesar el contenido del archivo


    # Paso 2: Crear el archivo CSV llamando a la función create_file



        
        # Paso 2: Iterar sobre las filas del archivo y formatear la información


# Paso 3: Llamar a la función contents_of_file y mostrar el resultado
print(contents_of_file("flowers.csv"))

# %%
import os
import csv

def create_file(filename):
    with open(filename, "w") as file:
        file.write("name,color,type\n")
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

def contents_of_file(filename):
    return_string = ""
    create_file(filename)

    with open(filename, "r") as file:
        reader = csv.DictReader(file)
        
        for row in reader:
            return_string += "A {} {} is {}\n".format(row["color"], row["name"], row["type"])

    return return_string

print(contents_of_file("flowers.csv"))
