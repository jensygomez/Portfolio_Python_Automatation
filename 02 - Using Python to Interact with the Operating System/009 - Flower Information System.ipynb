# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst and Automatation with Python
#
# **Date:**         13 March 2024
#
# **Modified** 17 March 2024
#
# **Location:**     Vila Izabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# **Title:**
#
# # Flower Information System
#
# **Prompt:** You are tasked with creating a Python program that manages information about different types of flowers. The program should be able to create a CSV file with information about various flowers, including their name, color, and type (annual or perennial). Additionally, it should read the contents of the CSV file and provide a formatted string containing details about each flower.
#
# **Step-by-step:**
#
# 1.  **Define a function -create_file(filename)- to create a CSV file:** This function should take a filename as input and create a CSV file with the specified filename. The CSV file should include a header row with column names (name, color, type) and data rows for several flowers, each containing the name, color, and type of the flower.
#
# 2.  **Define a function -contents_of_file(filename)- to read the contents of the CSV file:** This function should take a filename as input, call the create_file function to ensure that the CSV file exists, and then read the contents of the CSV file. It should parse each row and construct a formatted string containing information about each flower, including its color, name, and type. Finally, it should return this formatted string.
#
# 3.  **Call the function to read and print the contents of the CSV file:** This step involves calling the function created in step 2, passing the filename as an argument, and printing the returned string to display the flower information.

# %%
# Import the os module, which provides a way to interact with the operating system


# Import the csv module, which provides classes to read and write tabular data in CSV format



# Step 1: Define a function -create_file(filename)- to create a CSV file:





        # Write data rows
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

# Step 2: Define a function -contents_of_file(filename)- to read the contents of the CSV file: 


    # Initialize an empty string variable to store formatted flower information

    
    # Call create_file function to ensure the CSV file exists


    
    # Open the CSV file for reading


        # Create a CSV reader object to iterate over rows in the file

        
        # Skip the header row in the CSV file

        
        # Iterate over each row in the CSV file


            # Unpack values from the current row into variables


            
            # Format and append flower information to return_string


    
    # Return the formatted string containing information about flowers

    





# Step 3: Call the function to read and print the contents of the CSV file:
print(contents_of_file("flowers.csv"))

# %%
import os
import csv

def create_file(filename):
    with open(filename, "w") as file:
        file.write("name,color,type\n")
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

def contents_of_file(filename):
    return_string = ""
    create_file(filename)
    with open(filename, "r") as file:
        rows = csv.reader(file)
        next(rows)
        for row in rows:
            name, color, plant_type = row
            return_string += "a {} {} is {}\n".format(color, name, plant_type)
    return return_string

print(contents_of_file("flowers.csv"))
