# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst and Automatation with Python
#
# **Date:**         13 March 2024
#
# **Modified** 17 March 2024 -->26 March 2024
#
# **Location:**     Vila Izabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# **Título:**
# # Creación y lectura de archivo CSV de flores
# **Escenario:** Un programa Python que crea un archivo CSV llamado "flowers.csv" con datos de flores y luego lee el contenido del archivo para generar una cadena de texto formateada.
# **Paso a paso:**
# 1. **Importación de módulos:** Importa los módulos `os` y `csv` para manejar archivos y trabajar con archivos CSV, respectivamente.
# 2. **Definición de la función `create_file`:** Define una función llamada `create_file` que toma un argumento `filename` y escribe datos en un archivo con ese nombre.
#     - Abre el archivo especificado en modo escritura.
#     - Escribe una línea de encabezado con los nombres de las columnas: "name,color,type".
#     - Escribe filas de datos de flores en el archivo, cada una con el nombre, color y tipo de planta separados por comas.
# 3. **Definición de la función `contents_of_file`:** Define una función llamada `contents_of_file` que toma un argumento `filename` y devuelve una cadena de texto que representa el contenido formateado del archivo.
#     - Llama a la función `create_file` para asegurarse de que el archivo "flowers.csv" exista y tenga datos.
#     - Abre el archivo en modo lectura.
#     - Utiliza `csv.reader` para leer las filas del archivo CSV, omitiendo la primera fila que contiene el encabezado.
#     - Itera sobre las filas leídas y formatea la información de cada fila en una cadena de texto, agregándola a `return_string`.
#     - La cadena formateada sigue el patrón "a {color} {name} is {plant_type}\n".
# 4. **Impresión del contenido del archivo:** Fuera de la definición de la función, llama a `contents_of_file` con el nombre del archivo CSV "flowers.csv" y luego imprime el contenido devuelto por la función.

# %%
# 1. Importa los módulos `os` y `csv` para manejar archivos y trabajar con archivos CSV, respectivamente.


# 2. Define una función llamada `create_file` que toma un argumento `filename` y escribe datos en un archivo con ese nombre.

    #    - Abre el archivo especificado en modo escritura.


        #    - Escribe una línea de encabezado con los nombres de las columnas: "name,color,type".

        #    - Escribe filas de datos de flores en el archivo, cada una con el nombre, color y tipo de planta separados por comas.
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")


#3. Define una función llamada `contents_of_file` que toma un argumento `filename` y devuelve una cadena de texto que representa el contenido formateado del archivo.

    #   - Crea la Varible "return_string" vacia

    #    - Llama a la función `create_file` para asegurarse de que el archivo "flowers.csv" exista y tenga datos.

    #    - Abre el archivo en modo lectura.

        #    - Dentro de la Variable "rows", Utiliza `csv.reader` para leer las filas del archivo CSV, omitiendo la primera fila que contiene el encabezado.


        #    - Itera sobre las filas leídas y formatea la información de cada fila en una cadena de texto, agregándola a `return_string`.

            #    - La cadena formateada sigue el patrón "a {color} {name} is {plant_type}\n".


    #4. Fuera de la definición de la función, llama a `contents_of_file` con el nombre del archivo CSV "flowers.csv" y luego imprime el contenido devuelto por la función.

   

# Step 3: Call the function to read and print the contents of the CSV file:
print(contents_of_file("flowers.csv"))

# %%
import os
import csv

def create_file(filename):
    with open(filename, "w") as file:
        file.write("name,color,type\n")
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

def contents_of_file(filename):
    return_string = ""
    create_file(filename)
    with open(filename, "r") as file:
        rows = csv.reader(file)
        next(rows)
        for row in rows:
            name, color, plant_type = row
            return_string += "a {} {} is {}\n".format(color, name, plant_type)
    return return_string

print(contents_of_file("flowers.csv"))
