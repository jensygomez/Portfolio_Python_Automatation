# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst and Automatation with Python
#
# **Date:**         13 March 2024
#
# **Modified**  25 March 2024
#
# **Location:**     Vila Izabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# **Título:**
# # Generación y lectura de un archivo CSV de flores.
#
# **Escenario:** Una aplicación que necesita generar un archivo CSV que contiene información sobre diferentes tipos de flores, incluyendo su nombre, color y tipo (anual o perenne). Luego, la aplicación lee este archivo y devuelve una cadena formateada con la información de las flores.
#
# **Paso a paso:**
# 1. **Creación del archivo CSV:** Se define una función llamada `create_file(filename)` que recibe como argumento el nombre del archivo a crear. Esta función abre el archivo en modo escritura ("w") y escribe las líneas de encabezado y los datos de las flores en el archivo CSV.
# 2. **Contenido del archivo:** Se define una función llamada `contents_of_file(filename)` que recibe el nombre del archivo CSV como argumento. Dentro de esta función:
#    - Se llama a la función `create_file(filename)` para asegurarse de que el archivo esté creado y tenga datos.
#    - Se abre el archivo en modo lectura ("r") y se utiliza `csv.DictReader` para leer el contenido del archivo CSV, que convierte cada fila en un diccionario.
#    - Se recorre cada fila del archivo leído y se formatea una cadena de retorno que contiene información sobre cada flor, incluyendo su color, nombre y tipo.
#    - Se devuelve la cadena generada con la información de las flores.
# 3. **Impresión del contenido:** Finalmente, se imprime en la consola el resultado de llamar a la función `contents_of_file("flowers.csv")`, que mostrará la información de las flores contenidas en el archivo CSV generado.

# %%
# Paso 0: Importación de bibliotecas necesarias
# Biblioteca para interactuar con el sistema operativo "os"
# Biblioteca para trabajar con archivos CSV "csv"



#Se define una función llamada `create_file(filename)` que recibe como argumento el nombre del archivo a crear. 

    # Esta función abre el archivo en modo escritura ("w") y escribe las líneas de encabezado y los datos de las flores en el archivo CSV.
   
        file.write("name,color,type\n")
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

#  Se define una función llamada `contents_of_file(filename)` que recibe el nombre del archivo CSV como argumento.


    # Creamo la variable "return_string" como una cadena string vacia


    # Se llama a la función `create_file(filename)` para asegurarse de que el archivo esté creado y tenga datos.


    # e abre el archivo en modo lectura ("r")
  
  
        # creamo la variable "reader", que almacena  `csv.DictReader` para leer el contenido del archivo CSV, que convierte cada fila en un diccionario.
  


        #  Se recorre cada fila del archivo leído  


            # se formatea una cadena de retorno que contiene información sobre cada flor, incluyendo su color, nombre y tipo.



    # Se devuelve la cadena generada con la información de las flores.



print(contents_of_file("flowers.csv"))

# %%
import os
import csv

def create_file(filename):
    with open(filename, "w") as file:
        file.write("name,color,type\n")
        file.write("carnation,pink,annual\n")
        file.write("daffodil,yellow,perennial\n")
        file.write("iris,blue,perennial\n")
        file.write("poinsettia,red,perennial\n")
        file.write("sunflower,yellow,annual\n")

def contents_of_file(filename):
    return_string = ""
    create_file(filename)

    with open(filename, "r") as file:
        reader = csv.DictReader(file)
        
        for row in reader:
            return_string += "A {} {} is {}\n".format(row["color"], row["name"], row["type"])

    return return_string

print(contents_of_file("flowers.csv"))
